# %% [markdown]
# **COMPARING DBSCAN AND K-MEANS CLUSTERING**

# %% [markdown]
# **IMPORT RELEVANT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# **READ IN DATASET**

# %%
blobs = pd.read_csv('cluster_blobs.csv')

# %%
blobs
# Out:
#             X1        X2
# 0     4.645333  6.822294
# 1     4.784032  6.422883
# 2    -5.851786  5.774331
# 3    -7.459592  6.456415
# 4     4.918911  6.961479
# ...        ...       ...
# 1495  0.882673 -6.786272
# 1496  0.946854 -7.254512
# 1497  3.180138  6.608660
# 1498  5.454552  6.461246
# 1499 -7.769230  7.014384
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(data=blobs, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
moons = pd.read_csv('cluster_moons.csv')

# %%
moons
# Out:
#             X1        X2
# 0     0.674362 -0.444625
# 1     1.547129 -0.239796
# 2     1.601930 -0.230792
# 3     0.014563  0.449752
# 4     1.503476 -0.389164
# ...        ...       ...
# 1495  1.957344  0.187184
# 1496  0.962394  0.384304
# 1497 -0.761893  0.581666
# 1498  1.803858 -0.154705
# 1499  0.203305  0.079049
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(data=moons, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
circles = pd.read_csv('cluster_circles.csv')

# %%
circles
# Out:
#             X1        X2
# 0    -0.348677  0.010157
# 1    -0.176587 -0.954283
# 2     0.301703 -0.113045
# 3    -0.782889 -0.719468
# 4    -0.733280 -0.757354
# ...        ...       ...
# 1495 -0.297506  0.077834
# 1496  0.082555 -0.270371
# 1497  0.279533 -0.109435
# 1498  0.027432 -0.264891
# 1499 -0.216732  0.183006
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(data=circles, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
def display_categories(model, data):
    labels = model.fit_predict(data)
    sns.scatterplot(data=data, x='X1',y='X2', hue=labels, palette='Set1')

# %%
KMeans_Model = KMeans(n_clusters=3)
display_categories(model=KMeans_Model, data=blobs)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
KMeans_Model = KMeans(n_clusters=2)
display_categories(model=KMeans_Model, data=moons)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
KMeans_Model = KMeans(n_clusters=2)
display_categories(model=KMeans_Model, data=circles)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
DBSCAN_Model = DBSCAN()
display_categories(model=DBSCAN_Model, data=blobs)

# %%
DBSCAN_Model = DBSCAN(eps=0.15)
display_categories(model=DBSCAN_Model, data=moons)

# %%
DBSCAN_Model = DBSCAN(eps=0.15)
display_categories(model=DBSCAN_Model, data=circles)

# %% [markdown]
# **IMPLEMENTING DBSCAN WITH HYPERPARAMETER SEARCH**

# %%
two_blobs = pd.read_csv('cluster_two_blobs.csv')

# %%
two_blobs
# Out:
#            X1        X2
# 0    0.046733  1.765120
# 1   -8.994134 -6.508186
# 2    0.650539  1.264533
# 3   -9.501554 -6.736493
# 4    0.057050  0.188215
# ..        ...       ...
# 995 -9.895227 -6.644544
# 996 -9.544007 -6.060362
# 997  0.713958  1.560460
# 998  0.954444  0.889178
# 999 -8.867767 -5.635758
#
# [1000 rows x 2 columns]

# %%
sns.scatterplot(data=two_blobs, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
two_blobs_outliers = pd.read_csv('cluster_two_blobs_outliers.csv')

# %%
two_blobs_outliers
# Out:
#             X1        X2
# 0     0.046733  1.765120
# 1    -8.994134 -6.508186
# 2     0.650539  1.264533
# 3    -9.501554 -6.736493
# 4     0.057050  0.188215
# ...        ...       ...
# 998   0.954444  0.889178
# 999  -8.867767 -5.635758
# 1000 -4.000000 -2.000000
# 1001  0.000000 -8.000000
# 1002 -8.000000  0.000000
#
# [1003 rows x 2 columns]

# %%
sns.scatterplot(data=two_blobs_outliers, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
def display_categories(model, data):
    labels = model.fit_predict(data)
    sns.scatterplot(data=data, x='X1',y='X2', hue=labels, palette='Set1')

# %%
DBSCAN_Model = DBSCAN()

# %%
display_categories(model=DBSCAN_Model, data=two_blobs)

# %%
display_categories(model=DBSCAN_Model, data=two_blobs_outliers)

# %%
DBSCAN_Model_Parameter = DBSCAN(eps=1.5)
display_categories(model=DBSCAN_Model_Parameter, data=two_blobs_outliers)

# %%
DBSCAN_Model_Parameter.labels_
# Out:
# array([ 0,  1,  0, ..., -1, -1, -1], dtype=int64)

# %%
# total outliers found
np.sum(DBSCAN_Model_Parameter.labels_ == -1)
# Out:
# 3

# %%
# percentage of points classified as outliers
100 * np.sum(DBSCAN_Model_Parameter.labels_ == -1) / len(DBSCAN_Model_Parameter.labels_)
# Out:
# 0.29910269192422734

# %%
len(DBSCAN_Model_Parameter.labels_)
# Out:
# 1003

# %%
outlier_percent = []
number_of_outliers = []

for eps in np.linspace(0.001,7,200):
    DBSCAN_Model_Parameter = DBSCAN(eps=eps)
    DBSCAN_Model_Parameter.fit(two_blobs_outliers)
    
    # total outliers found
    number_of_outliers.append(np.sum(DBSCAN_Model_Parameter.labels_ == -1))
    
    # percentage of points classified as outliers
    perc_outliers = 100 * np.sum(DBSCAN_Model_Parameter.labels_ == -1) / len(DBSCAN_Model_Parameter.labels_)
    
    outlier_percent.append(perc_outliers)

# %%
sns.lineplot(x=np.linspace(0.001,7,200), y=number_of_outliers)
plt.xlim(0,2)
plt.ylim(0,10)
plt.ylabel('Percentage of Points Classified as Outliers')
plt.hlines(y=3, xmin=0, xmax=2, color='red')

# %%
outlier_percent = []
number_of_outliers = []

for n in np.arange(1,100):
    DBSCAN_Model_Parameter = DBSCAN(min_samples=n)
    DBSCAN_Model_Parameter.fit(two_blobs_outliers)
    
    # total outliers found
    number_of_outliers.append(np.sum(DBSCAN_Model_Parameter.labels_ == -1))
    
    # percentage of points classified as outliers
    perc_outliers = 100 * np.sum(DBSCAN_Model_Parameter.labels_ == -1) / len(DBSCAN_Model_Parameter.labels_)
    
    outlier_percent.append(perc_outliers)

# %%
sns.lineplot(x=np.arange(1,100), y=outlier_percent)
plt.xlabel('Minimum Number of Samples')
plt.ylabel('Percentage of Points Classified as Outliers')
# Out:
# Text(0, 0.5, 'Percentage of Points Classified as Outliers')

# %% [markdown]
# **FINAL MODEL**

# %%
num_dim = two_blobs_outliers.shape[1]
DBSCAN_Model_Final = DBSCAN(min_samples=2*num_dim, eps=0.75)
display_categories(model=DBSCAN_Model_Final, data=two_blobs_outliers)
