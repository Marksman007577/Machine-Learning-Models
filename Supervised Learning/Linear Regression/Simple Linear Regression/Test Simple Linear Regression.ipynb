# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy as sp

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv('Advertising.csv')

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.pairplot(data=df)

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.30, random_state=101)

# %%
X_train
# Out:
#         TV  radio  newspaper
# 85   193.2   18.4       65.7
# 183  287.6   43.0       71.8
# 127   80.2    0.0        9.2
# 53   182.6   46.2       58.7
# 100  222.4    4.3       49.8
# ..     ...    ...        ...
# 63   102.7   29.6        8.4
# 70   199.1   30.6       38.7
# 81   239.8    4.1       36.9
# 11   214.7   24.0        4.0
# 95   163.3   31.6       52.9
#
# [140 rows x 3 columns]

# %%
X_test
# Out:
#         TV  radio  newspaper
# 37    74.7   49.4       45.7
# 109  255.4   26.9        5.5
# 31   112.9   17.4       38.6
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2
# 119   19.4   16.0       22.3
# 54   262.7   28.8       15.9
# 74   213.4   24.6       13.1
# 145  140.3    1.9        9.0
# 142  220.5   33.2       37.9
# 148   38.0   40.3       11.9
# 112  175.7   15.4        2.4
# 174  222.4    3.4       13.1
# 55   198.9   49.4       60.0
# 141  193.7   35.4       75.6
# 149   44.7   25.8       20.6
# 25   262.9    3.5       19.5
# 34    95.7    1.4        7.4
# 170   50.0   11.6       18.4
# 39   228.0   37.7       32.0
# 172   19.6   20.1       17.0
# 153  171.3   39.7       37.7
# 175  276.9   48.9       41.8
# 61   261.3   42.7       54.7
# 65    69.0    9.3        0.9
# 50   199.8    3.1       34.6
# 42   293.6   27.7        1.8
# 129   59.6   12.0       43.1
# 179  165.6   10.0       17.6
# 2     17.2   45.9       69.3
# 12    23.8   35.1       65.9
# ...

# %%
y_train
# Out:
# 85     15.2
# 183    26.2
# 127     8.8
# 53     21.2
# 100    11.7
#        ...
# 63     14.0
# 70     18.3
# 81     12.3
# 11     17.4
# 95     16.9
# Name: sales, Length: 140, dtype: float64

# %%
y_test
# Out:
# 37     14.7
# 109    19.8
# 31     11.9
# 89     16.7
# 66      9.5
# 119     6.6
# 54     20.2
# 74     17.0
# 145    10.3
# 142    20.1
# 148    10.9
# 112    14.1
# 174    11.5
# 55     23.7
# 141    19.2
# 149    10.1
# 25     12.0
# 34      9.5
# 170     8.4
# 39     21.5
# 172     7.6
# 153    19.0
# 175    27.0
# 61     24.2
# 65      9.3
# 50     11.4
# 42     20.7
# 129     9.7
# 179    12.6
# 2       9.3
# 12      9.2
# 133    19.6
# 90     11.2
# 22      5.6
# 41     17.1
# 32      9.6
# 125    10.6
# 196     9.7
# 158     7.3
# 180    10.5
# 16     12.5
# 186    10.3
# 144    11.4
# 121     7.0
# 80     11.8
# 18     11.3
# 78      5.3
# 48     14.8
# 4      12.9
# 15     22.4
# 1      10.4
# 43     12.9
# 102    14.8
# 164    11.9
# 9      10.6
# 155     3.2
# 36     25.4
# 190    10.8
# 33     17.4
# 45     14.9
# Name: sales, dtype: float64

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_bar = model.predict(X_test)

# %%
y_bar
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
error = y_test-y_bar

# %%
error
# Out:
# 37    -1.041313
# 109    0.189374
# 31     0.451111
# 89    -0.308198
# 66     0.327143
# 119   -0.412483
# 54    -0.089925
# 74    -0.299540
# 145    0.524155
# 142    0.878058
# 148   -1.505032
# 112    0.207650
# 174   -2.225411
# 55     2.412060
# 141    0.775434
# 149    0.118016
# 25    -3.552290
# 34     1.810863
# 170    0.843850
# 39     1.096888
# 172   -0.192152
# 153    0.757859
# 175    2.313681
# 61     1.378009
# 65     1.320379
# 50    -1.252073
# 42    -0.769259
# 129    1.647714
# 179    0.176840
# 2     -3.207197
# 12    -1.577578
# 133    0.355399
# 90     1.129731
# 22    -1.107800
# 41    -0.214921
# 32     1.832357
# 125    1.346067
# 196    1.421653
# 158   -3.281056
# 180   -0.135911
# 16    -0.510026
# 186    0.528079
# 144    1.185301
# 121   -1.045720
# 80     0.232893
# 18     1.216320
# 78    -3.698066
# 48    -1.453889
# 4     -0.339423
# 15     1.585066
# 1     -2.097274
# 43    -1.066159
# 102   -2.762851
# 164    0.754630
# 9     -1.962615
# ...

# %%
MAE = mean_absolute_error(y_test, y_bar)

# %%
MAE
# Out:
# 1.2137457736144803

# %%
MSE = mean_squared_error(y_test, y_bar)

# %%
MSE
# Out:
# 2.2987166978863782

# %%
RMSE = math.sqrt(MSE)

# %%
RMSE
# Out:
# 1.516151937599388

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.scatterplot(x=y_test, y=error)
plt.axhline(y=0, color='r', ls='--')

# %%
# plotting the distribution
plt.figure(figsize=(10,5), dpi=200)
sns.displot(error, bins=20, kde=True)

# %%
# Normal probability plot
# Helps to compare what a normal distribution plot (red line) would look like against your plot/values
fig, ax = plt.subplots(figsize=(6,5), dpi=200)
_ = sp.stats.probplot(error, plot=ax)

# %%
model.coef_
# Out:
# array([ 0.04469599,  0.1875657 , -0.00032275])

# %%
# Visualizing the prediction against the true features value
y_bar_allfeatures = model.predict(X)

# %%
y_bar_allfeatures
# Out:
# array([20.50372383, 12.49727439, 12.50719678, 17.65055218, 13.23942315,
#        12.68813825, 11.8661167 , 12.19652898,  3.92947753, 12.56261468,
#         7.18600237, 17.24804235, 10.77757812,  8.93256162, 18.43004394,
#        20.81493419, 13.01002595, 23.13857144, 10.08368001, 14.21190226,
#        18.09146662, 14.71135594,  6.70779999, 16.51702626,  8.29350861,
#        15.55228966, 15.03019258, 17.00799092, 19.34752936,  9.2949468 ,
#        21.53714962, 11.44888935,  7.76764327, 18.77399978,  7.68913693,
#        16.91092798, 23.29465134, 15.74131332, 10.07459969, 20.40311209,
#        16.37498155, 17.31492147, 21.46925937, 13.96615898,  9.07985953,
#        15.18785675,  9.00613553, 21.65210124, 16.25388914,  8.32433012,
#        12.65207264,  9.43847332, 20.63244845, 19.95960496, 20.28992463,
#        21.28794031,  8.73504177, 12.83502482, 21.86453317, 18.09915914,
#         5.9109869 , 22.82199068, 16.74573517, 13.29103892, 17.02965596,
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,6))

axes[0].plot(df['TV'], df['sales'], 'o')
axes[0].plot(df['TV'], y_bar_allfeatures, 'o', color='red')
axes[0].set_ylabel('Sales')
axes[0].set_title('TV Spend')

axes[1].plot(df['radio'], df['sales'], 'o')
axes[1].plot(df['radio'], y_bar_allfeatures, 'o', color='red')
axes[1].set_title('Radio Spend')
axes[1].set_ylabel('Sales')

axes[2].plot(df['newspaper'], df['sales'], 'o')
axes[2].plot(df['newspaper'], y_bar_allfeatures, 'o', color='red')
axes[2].set_title('Newspaper Spend');
axes[2].set_ylabel('Sales')


plt.tight_layout();
